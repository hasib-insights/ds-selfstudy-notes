# %% [markdown]
# <a href="https://colab.research.google.com/github/hasib-insights/My_data-Science_self-study_notes/blob/main/01_Python_basics/01_variables_data_types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables

# %%
my_favotite_color = "Gray"

# %%
my_favotite_color
# Out:
# 'Gray'

# %% [markdown]
# Multiple variables in a single statement

# %%
color_1, color_2, color_3 = "Red", "Gray", "Green"

# %%
color_1
# Out:
# 'Red'

# %%
color_2
# Out:
# 'Gray'

# %%
color_3
# Out:
# 'Green'

# %% [markdown]
# Same value to multiple variables

# %%
color_4 = color_5 = color_6 = "Blue"

# %%
color_4
# Out:
# 'Blue'

# %%
color_5
# Out:
# 'Blue'

# %%
color_6
# Out:
# 'Blue'
